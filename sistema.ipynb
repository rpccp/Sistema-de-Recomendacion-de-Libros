# %%
import pandas as pd
df = pd.read_csv('books.csv')
df
# Out:
#              isbn13      isbn10                      title  \
# 0     9780002005883  0002005883                     Gilead
# 1     9780002261982  0002261987               Spider's Web
# 2     9780006163831  0006163831               The One Tree
# 3     9780006178736  0006178731             Rage of angels
# 4     9780006280897  0006280897             The Four Loves
# ...             ...         ...                        ...
# 6805  9788185300535  8185300534                  I Am that
# 6806  9788185944609  8185944601       Secrets Of The Heart
# 6807  9788445074879  8445074873             Fahrenheit 451
# 6808  9789027712059  9027712050   The Berlin Phenomenology
# 6809  9789042003408  9042003405  'I'm Telling You Stories'
#
#                                             subtitle  \
# 0                                                NaN
# 1                                            A Novel
# 2                                                NaN
# ...

# %%
def representacion_textual(columna):
    representacion_textual = f"""Titulo: {columna['title']}
Autores: {columna['authors']}
Descripcion: {columna['description']}
Categorias: {columna['categories']}
Anio de Publicacion: {columna['published_year']}
Rating Promedio: {columna['average_rating']}
Numero de Paginas: {columna['num_pages']}
"""
    return representacion_textual

# %%
df['representacion_textual'] = df.apply(representacion_textual, axis=1)

# %%
import faiss
import requests
import numpy as np

dim = 4096

indice = faiss.IndexFlatL2(dim)

X = np.zeros((len(df['representacion_textual']), dim), dtype='float32')

# %%
for i, representacion in enumerate(df['representacion_textual']):
    if i % 100 == 0:
        print(i)


    respuesta = requests.post('http//localhost:11434/api/embeddings',
                              json = {
                                  'model': 'llama2', 
                                  'prompt': representacion
                              })
    embedding = respuesta.json()['embedding']

    X[i] = np.array(embedding)

indice.add(X)
# Out:
# 0
# ---------------------------------------------------------------------------
# MissingSchema                             Traceback (most recent call last)
# Cell In[12], line 6
#       2 if i % 100 == 0:
#       3     print(i)
# ----> 6 respuesta = requests.post('http//localhost:11434/api/embeddings',
#       7                           json = {
#       8                               'model': 'llama2',
#       9                               'prompt': representacion
#      10                           })
#      11 embedding = respuesta.json()['embedding']
#      13 X[i] = np.array(embedding)
#
# File c:\Users\rgasp\anaconda3\Lib\site-packages\requests\api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# ...
